# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
import urllib.parse
from ast import *

# %%
location = "san francisco bay area"
topic = "economy"

# %%
def scrape_article(url):
    # Send a request to the URL
    response = requests.get(url)

    # Check if the request was successful
    # if response.status_code != 200:
      #  raise Exception(f"Failed to load page {url}, status code: {response.status_code}")

    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the relevant content
    # This part depends on the structure of the website. We'll use an example of a common structure.
    article_content = ''

    # Many news websites use <article> tag or specific class names for article content
    article = soup.find('article')
    if article:
        paragraphs = article.find_all('p')
    else:
        # Fallback to a generic method, searching for <p> tags within a div with a common class name
        paragraphs = soup.find_all('p')

    for p in paragraphs:
        article_content += p.get_text() + '\n'

    return article_content.strip()

# %%
def get_news_search_results(query, num_results):
    # Google news search URL with query
    search_url = f"https://www.google.com/search?q={query}&tbm=nws&num={num_results}"

    # Send a request to Google Search
    response = requests.get(search_url, headers={"User-Agent": "Mozilla/5.0"})
    response.raise_for_status()  # Check if the request was successful

    # Parse the response content with BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract the news headlines
    #soup.find_all('div', class_= 'BNeawe vvjwJb AP7Wnd'):
    
    divs = soup.find_all('div', class_='BNeawe vvjwJb AP7Wnd')
    articles = []
    
    if not divs:
        print("No news results found.")
        return
    
    for div in divs:
        # Extract headline text
        headline = div.text
        # Find the parent 'a' tag which contains the link
        link_tag = div.find_parent('a')
        # Extract the link URL
        if link_tag:
            # Google search results URLs are often prefixed with '/url?q='
            # Extract and decode the actual URL using urllib.parse
            raw_url = link_tag.get('href')
            if raw_url.startswith('/url?q='):
                url = urllib.parse.unquote(raw_url.split('/url?q=')[1].split('&sa=')[0])
            else:
                url = 'No valid link found'
        else:
            url = 'No link found'
            
        articles.append((headline, url))
            
    return articles

# %%
# Define the query and the number of results
query = f"{location} local news in the past week about {topic}"
num_results = 100
articles = []

# Get the news search results
news_search_results = get_news_search_results(query, num_results)

# Print the results
for i, result in enumerate(news_search_results, 1):
    # print(f"{i}. {result}")
    articles.append(result)

# %%
articles
# Out:
# [('Downtown San Jose visit activity soars, Oakland jumps, San Francisco nosedives',
#   'https://www.mercurynews.com/2024/05/09/economy-san-jose-oakland-downtown-jobs-restaurant-store-tech-property/'),
#  ('25000 fans headed to San Francisco for sold out rave with Skrillex, Fred Again',
#   'https://abc7news.com/post/sold-rave-25000-fans-headed-san-francisco-skrillex/14888819/'),
#  ('The APEC summit is happening this week in San Francisco. What is APEC, anyway?',
#   'https://www.nbcbayarea.com/news/local/apec-summit-san-francisco-explained/3369623/'),
#  ('How the Tri-Valley drives the local economy, embraces innovation - San Francisco Business Times',
#   'https://www.bizjournals.com/sanfrancisco/news/2024/02/16/tri-valley-drives-economy-embraces-innovation.html'),
#  ('What Happened to San Francisco, Really?',
#   'https://www.newyorker.com/magazine/2023/10/23/what-happened-to-san-francisco-really'),
#  ("Protesters Shut Down I-880 Freeway in Oakland as Part of 'Economic Blockade' for Gaza",
#   'https://www.kqed.org/news/11982940/protesters-shut-down-880-freeway-in-oakland-as-part-of-economic-blockade-for-gaza'),
#  ('APEC in San Francisco: Biden, Harris attend fundraiser as protesters chant outside',
#   'https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-18481349.php'),
#  ('Bay Area and California add jobs in April — but the gains are puny',
#   'https://www.mercurynews.com/2024/05/17/bay-area-job-tech-economy-covid-layoff-hotel-restaurant-store-april/'),
#  ("Here's what San Francisco's streets look like 3 weeks after APEC",
#   'https://www.nbcbayarea.com/news/local/san-francisco/san-francisco-streets-after-apec/3395312/'),
#  ('From Street Closures to Security Checks, What to Know About SF APEC 2023',
#   'https://www.kqed.org/news/11965942/from-street-closures-to-security-checks-what-to-know-about-sf-apec-2023'),
#  ('As APEC events wrap up, many San Francisco Chinatown businesses wait for the economic boost',
#   'https://abc7news.com/sf-chinatown-apec-business-san-francisco/14073667/'),
#  ("Thousands march against APEC in S.F.'s first major protest of summit",
#   'https://www.sfchronicle.com/bayarea/article/apec-protest-san-francisco-18483819.php'),
#  ('Oakland International Airport to add San Francisco Bay to name — legal war looms',
#   'https://www.mercurynews.com/2024/04/11/oakland-airport-san-francisco-bay-name-travel-economy-court-airline/'),
#  ('APEC Summit 2023: Day-by-day schedule of Asia Pacific Economic Cooperation in San Francisco',
#   'https://abc7news.com/apec-summit-san-francisco-schedule-asia-pacific-economic-cooperation-2023/14028661/'),
#  ("Trickle-down economics: Oakland Coliseum workers pay the price for A's move",
#   'https://www.sfchronicle.com/eastbay/article/oakland-coliseum-worker-employee-19397706.php'),
#  ('2023 APEC summit: Everything to know about San Francisco road closures, public transportation, security, tourism and more',
#   'https://abc7news.com/apec-2023-san-francisco-road-closures-summit-security-sf-safety/14022548/'),
#  ("When will San Francisco's economy hit bottom? Here's what experts say",
#   'https://www.sfchronicle.com/sf/article/san-francisco-economy-18362987.php'),
#  ('APEC in SF: Clearing homeless hot spots a priority for city',
#   'https://www.sfchronicle.com/sf/article/sf-apec-homeless-encampments-clear-hotspots-18478050.php'),
#  ('2025 NBA All-Star Game weekend to bring big boost to San Francisco Bay Area economy',
#   'https://abc7news.com/2025-nba-all-star-game-san-francisco-chase-center-tourism/14019899/'),
#  ('How APEC summit will make your San Francisco commute harder for an entire week',
#   'https://abc7news.com/apec-summit-san-francisco-road-closures-traffic/14009814/'),
#  ('APEC in San Francisco: Storms slow traffic as Biden hosts leaders at Legion of Honor, Harris leaves for L.A.',
#   'https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-protests-18494935.php'),
#  ("Drug addicts, homeless plaguing San Francisco's downtown miraculously disappear ahead of Biden, Xi Jinping summit",
#   'https://nypost.com/2023/11/10/news/san-francisco-clears-drug-addicts-and-homeless-out-of-downtown-ahead-of-biden-and-xi-jinping-summit/'),
#  ('Guide to San Francisco Fleet Week 2023',
#   'https://www.cbsnews.com/sanfrancisco/news/guide-to-san-francisco-fleet-week-2023/'),
#  ('California struggles with skyrocketing gas prices as summer comes to a close',
#   'https://www.cbsnews.com/sanfrancisco/news/california-struggles-with-skyrocketing-gas-prices-as-summer-comes-to-a-close/'),
#  ('APEC San Francisco: See Security, Traffic, Transit Maps',
#   'https://sfstandard.com/2023/11/07/san-francisco-apec-security-maps-transit-traffic/'),
#  ('49ers report: Levi’s Stadium generated more than $2 billion in the local economy since 2014 opening',
#   'https://www.mercurynews.com/2023/10/02/49ers-report-levis-stadium-generated-more-than-2-billion-in-the-local-economy-since-2014-opening/'),
#  ("Economists blast 49ers' report on Levi's Stadium's local impact",
#   'https://www.sfgate.com/49ers/article/levis-stadium-economic-impact-santa-clara-county-18404728.php'),
#  ("Silicon Valley's biotech sector is still going strong amid concerns about economy",
#   'https://www.axios.com/local/san-francisco/2023/08/03/silicon-valley-biotech-growth-economy'),
#  ('APEC 2023 in San Francisco: What to know, events schedule, street closures',
#   'https://www.nbcbayarea.com/news/local/apec-san-francisco-schedule-street-closures/3347168/'),
#  ('The city making a comeback? Major events coming to San Francisco',
#   'https://www.nbcbayarea.com/news/local/san-francisco/major-events-coming-to-san-francisco/3364763/'),
#  ("S.F. is struggling and could be in for big 'doom loop'",
#   'https://www.sfchronicle.com/sf/article/city-economy-doom-loop-17846412.php'),
#  ('San Francisco police and Secret Service outline APEC security impacts',
#   'https://www.nbcbayarea.com/news/local/apec-san-francisco-security/3344623/'),
#  ('Some Bay Area Populations Struggling Financially in Post-COVID Economy: Report',
#   'https://www.nbcbayarea.com/news/local/bay-area-covid-financial-recovery/3193391/'),
#  ('California tourism recovers from pandemic and S.F. is almost there, new report finds',
#   'https://www.sfchronicle.com/california/article/california-tourism-recovers-pandemic-s-f-beats-19440850.php'),
#  ("'Doom, but not loop': Has San Francisco dodged the worst-case scenario?",
#   'https://www.sfchronicle.com/sf/article/doom-loop-city-economy-19449708.php'),
#  ('What is APEC, and what to expect in San Francisco',
#   'https://www.axios.com/local/san-francisco/2023/11/02/apec-sf-2023-map-location-dates'),
#  ('With tech workers gone, what is the future of San Francisco?',
#   'https://www.aljazeera.com/economy/2023/8/23/with-tech-workers-gone-what-is-the-future-of-san-francisco'),
#  ('SF sales down 28% from 2019. What sectors and areas were hit hardest?',
#   'https://www.sfchronicle.com/bayarea/article/sf-sales-tax-neighborhood-19394489.php'),
#  ('Golden Gate Bridge reopens, but protests may cause more traffic chaos',
#   'https://www.sfchronicle.com/bayarea/article/gaza-protest-interstate-880-oakland-19403609.php'),
#  ('APEC is set to bring traffic of epic proportions to the San Francisco Bay Area',
#   'https://www.sfchronicle.com/bayarea/article/san-francisco-apec-travel-roadblocks-muni-parking-18470643.php'),
#  ('San Francisco Bay Area is fastest-growing urban area in the country',
#   'https://www.axios.com/local/san-francisco/2022/11/15/san-francisco-bay-area-economic-growth'),
#  ('APEC summit kicks off in San Francisco with week full of lane closures, diplomatic discussions',
#   'https://abc7news.com/apec-summit-kick-off-san-francisco-president-joe-biden/14046017/'),
#  ('Thousands rally and march in San Francisco in protest against APEC and corporate power',
#   'https://www.mercurynews.com/2023/11/12/thousands-rally-and-march-in-san-francisco-in-protest-against-apec-and-corporate-power/'),
#  ('Downtown San Francisco showing signs of economic rebound amid closing retail storefronts and high office vacancy rates',
#   'https://abc7news.com/downtown-san-francisco-showing-signs-of-economic-rebound-amid-closing-retail-storefronts-high-office-vacancy-rates/14618584/'),
#  ("Despite downtown San Francisco's current rough patch, prominent business leaders are investing in it",
#   'https://abc7news.com/downtown-san-francisco-investing-in-sf-empty-offices-tech/13236684/'),
#  ("The APEC security zone is going up in S.F. behind tall fences. Here's what it looks like",
#   'https://www.sfchronicle.com/bayarea/article/apec-barriers-traffic-18485314.php'),
#  ('Here are five key takeaways from the Bay Area’s global summit',
#   'https://www.mercurynews.com/2023/11/18/here-are-five-key-takeaways-from-the-bay-areas-global-summit/'),
#  ('China’s Greater Bay Area among economic hubs in focus for closer US ties',
#   'https://www.scmp.com/news/china/diplomacy/article/3247045/chinas-push-closer-us-ties-focus-greater-bay-area-yangtze-economic-hubs'),
#  ('Are the Bay Area’s largest downtowns caught in a doom loop?',
#   'https://www.mercurynews.com/2023/05/07/are-the-bay-areas-largest-downtowns-caught-in-a-doom-loop/'),
#  ("San Francisco's Chinatown Businesses Look to Bounce Back Following COVID, Recent Crime",
#   'https://www.nbcbayarea.com/news/local/san-francisco-chinatown-businesses-covid-crime/3206351/'),
#  ('SFO demands different route for new Oakland International Airport name',
#   'https://www.mercurynews.com/2024/04/01/oakland-airport-travel-san-francisco-name-economy-airline-aviation-fly/'),
#  ("Tech layoffs may drive up Bay Area's unemployment rate",
#   'https://www.axios.com/local/san-francisco/2023/04/20/san-francisco-unemployment-tech-layoffs'),
#  ('Video replay: Watch the San Francisco Fleet Week Parade of Ships',
#   'https://www.cbsnews.com/sanfrancisco/news/how-to-watch-the-san-francisco-fleet-week-parade-of-ships/'),
#  ('Approaching Bay Area deadline a ‘test case’ for California’s housing crisis',
#   'https://www.mercurynews.com/2024/01/25/approaching-bay-area-deadline-a-test-case-for-californias-housing-crisis/'),
#  ('The Bay Area’s economy of mud: Dredging concerns threaten jobs, $100 billion in assets',
#   'https://www.mercurynews.com/2023/04/10/the-bay-areas-economy-of-mud-dredging-concerns-threaten-jobs-100-billion-in-assets/'),
#  ('Move over, San Francisco: The suburbs of Silicon Valley are calling',
#   'https://www.mercurynews.com/2023/08/29/move-over-san-francisco-the-suburbs-of-silicon-valley-are-calling/'),
#  ('Bay Area office vacancies balloon to all-time high as tech wobbles',
#   'https://www.mercurynews.com/2024/01/02/san-jose-san-francisco-silicon-valley-office-real-estate-tech-economy/'),
#  ('The Farmers Had What the Billionaires Wanted',
#   'https://www.nytimes.com/2024/01/19/business/economy/flannery-california-forever-solano.html'),
#  ('Video replay: Watch the San Francisco Fleet Week Blue Angels Friday afternoon air show',
#   'https://www.cbsnews.com/sanfrancisco/news/how-to-watch-the-san-francisco-fleet-week-blue-angels-air-show/'),
#  ("Swarmed by Swifties: Bay Area businesses reap rewards with Taylor Swift's shows",
#   'https://www.sfchronicle.com/bayarea/article/taylor-swift-business-impact-18268669.php'),
#  ('San Jose adopts ‘anti-gentrification’ policy to set aside affordable apartments for locals',
#   'https://www.mercurynews.com/2024/03/29/san-jose-adopts-anti-gentrification-policy-to-set-aside-affordable-apartments-for-locals/'),
#  ('38 Pro-Palestinian protesters arrested after shutdown of Golden Gate Bridge, I-880 in Oakland, CHP says',
#   'https://abc7news.com/pro-palestinian-protesters-shut-down-golden-gate-bridge-and-i-880-in-oakland/14668534/'),
#  ('International sailing competition comes to San Francisco bay, bringing economic boost',
#   'https://abc7news.com/united-states-sail-grand-prix-sailgp-san-francisco-bay-sailing-race-team-usa/13219190/'),
#  ('Nordstrom to close both Downtown San Francisco stores, including Nordstrom Rack, company says',
#   'https://abc7news.com/nordstrom-san-francisco-closing-westfield-mall-nordstroms-store-downtown-stores-union-square/13205127/'),
#  ('Bay Area exodus: Wealthy resident departures worsen ‘doom loop’ fears',
#   'https://www.mercurynews.com/2023/04/13/bay-area-exodus-wealthy-resident-departures-worsen-doom-loop-fears/'),
#  ('Housing | - 5 charts that explain the California and Bay Area exodus',
#   'https://www.mercurynews.com/2023/05/21/5-charts-that-explain-the-california-and-bay-area-exodus/'),
#  ('The minimum wage just went up in several Bay Area cities–will it make a difference?',
#   'https://www.mercurynews.com/2023/07/08/the-minimum-wage-just-went-up-in-several-bay-area-cities-will-it-make-a-difference/'),
#  ('Bay Area tech layoffs top grim milestone after jobs cuts by Meta, Nuro, others',
#   'https://www.mercurynews.com/2023/06/01/bay-area-tech-layoffs-top-grim-milestone-after-jobs-cuts-by-meta-nuro-others/'),
#  ('As store signs come down, San Francisco mayor talks of recent demand for downtown office space',
#   'https://abc7news.com/downtown-san-francisco-sf-office-space-union-square-store-closing/13555307/'),
#  ("Report on Bay Area's racial-economic divide finds some Black residents living in persistent poverty",
#   'https://localnewsmatters.org/2022/08/04/report-on-bay-areas-racial-economic-divide-finds-some-blacks-living-in-persistent-poverty/'),
#  ("SF to host Asian-Pacific economic summit in 2023, event's first visit to States in 12 years",
#   'https://localnewsmatters.org/2022/12/03/sf-to-host-asian-pacific-economic-summit-in-2023-events-first-visit-to-states-in-12-years/'),
#  ('Coronavirus updates from the Bay Area: June 10-15, 2021',
#   'https://www.sfchronicle.com/coronavirus/article/Coronavirus-live-updates-Bay-Area-sees-plunge-in-15993567.php'),
#  ('Health officers sound alarm as California economy reopens',
#   'https://www.sandiegouniontribune.com/2020/06/23/health-officers-sound-alarm-as-california-economy-reopens/'),
#  ("Bribery, fraud and wildfire: How a PG&E contractor with a sketchy past made millions after California's deadliest fire",
#   'https://localnewsmatters.org/2020/06/30/bribery-fraud-and-wildfire-how-a-pge-contractor-with-a-sketchy-past-made-millions/'),
#  ('Bay Area falling behind on quake safety despite booming tech economy',
#   'https://www.sandiegouniontribune.com/2018/04/22/bay-area-falling-behind-on-quake-safety-despite-booming-tech-economy/'),
#  ("Bay Area economists look to a cooler future, 'day of reckoning' - San Francisco Business Times",
#   'https://www.bizjournals.com/sanfrancisco/news/2016/12/28/2017-forecast-economists-downturn-reckoning.html'),
#  ('In Cramped and Costly Bay Area, Cries to Build, Baby, Build (Published 2016)',
#   'https://www.nytimes.com/2016/04/17/business/economy/san-francisco-housing-tech-boom-sf-barf.html'),
#  ('Fleet Week Cancellation Impacts San Francisco Economy',
#   'https://www.nbcbayarea.com/news/local/fleet-week-cancellation-impacts-san-francisco-economy/1955902/'),
#  ('Half of Bay Area newspaper jobs gone in last decade',
#   'https://www.sfpublicpress.org/half-of-bay-area-newspaper-jobs-gone-in-last-decade/')]

# %%
def prompt_openai(prompt):
    api_key = "your key here"
    client = OpenAI(api_key=api_key)
    completion = client.chat.completions.create(
      model="gpt-4o",
      messages=[
        {"role": "user", "content": prompt}
      ]
    )
    return completion.choices[0].message.content

# %%
prompt = f"""For the following list, give me a list of important distinct events that are referenced by several articles (i.e. a short blurb). 
{articles} If it's not related to {topic} and/or it's not in {location}, don't account for it. If it's an opinion article or a guide, don't account for it.
It should be formatted as a python array of tuples, with the first item being the event title and the second item the links that pertain to it. The event should be something distinct and not a general topic — i.e. the Golden Gate Bridge has shut down."
Please don't do things like '''python or /n, i should be able to assign the output text to a variable
"""
response_text = prompt_openai(prompt)
print(response_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[34], line 6
#       1 prompt = f"""For the following list, give me a list of important distinct events that are referenced by several articles (i.e. a short blurb).
#       2 {articles} If it's not related to {topic} and/or it's not in {location}, don't account for it. If it's an opinion article or a guide, don't account for it.
#       3 It should be formatted as a python array of tuples, with the first item being the event title and the second item the links that pertain to it. The event should be something distinct and not a general topic — i.e. the Golden Gate Bridge has shut down."
#       4 Please don't do things like '''python or /n, i should be able to assign the output text to a variable
#       5 """
# ----> 6 response_text = prompt_openai(prompt)
#       7 print(response_text)
#
# Cell In[33], line 4, in prompt_openai(prompt)
#       2 api_key = "your key here"
#       3 client = OpenAI(api_key=api_key)
# ----> 4 completion = client.chat.completions.create(
#       5   model="gpt-4o",
#       6   messages=[
#       7     {"role": "user", "content": prompt}
#       8   ]
#       9 )
#      10 return completion.choices[0].message.content
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\resources\chat\completions.py:640, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     606 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     607 def create(
#     608     self,
#    (...)
#     638     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     639 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 640     return self._post(
#     641         "/chat/completions",
#     642         body=maybe_transform(
#     643             {
#     644                 "messages": messages,
#     645                 "model": model,
#     646                 "frequency_penalty": frequency_penalty,
#     647                 "function_call": function_call,
#     648                 "functions": functions,
#     649                 "logit_bias": logit_bias,
#     650                 "logprobs": logprobs,
#     651                 "max_tokens": max_tokens,
#     652                 "n": n,
#     653                 "parallel_tool_calls": parallel_tool_calls,
#     654                 "presence_penalty": presence_penalty,
#     655                 "response_format": response_format,
#     656                 "seed": seed,
#     657                 "service_tier": service_tier,
#     658                 "stop": stop,
#     659                 "stream": stream,
#     660                 "stream_options": stream_options,
#     661                 "temperature": temperature,
#     662                 "tool_choice": tool_choice,
#     663                 "tools": tools,
#     664                 "top_logprobs": top_logprobs,
#     665                 "top_p": top_p,
#     666                 "user": user,
#     667             },
#     668             completion_create_params.CompletionCreateParams,
#     669         ),
#     670         options=make_request_options(
#     671             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     672         ),
#     673         cast_to=ChatCompletion,
#     674         stream=stream or False,
#     675         stream_cls=Stream[ChatCompletionChunk],
#     676     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:1250, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1236 def post(
#    1237     self,
#    1238     path: str,
#    (...)
#    1245     stream_cls: type[_StreamT] | None = None,
#    1246 ) -> ResponseT | _StreamT:
#    1247     opts = FinalRequestOptions.construct(
#    1248         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1249     )
# -> 1250     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:931, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     922 def request(
#     923     self,
#     924     cast_to: Type[ResponseT],
#    (...)
#     929     stream_cls: type[_StreamT] | None = None,
#     930 ) -> ResponseT | _StreamT:
# --> 931     return self._request(
#     932         cast_to=cast_to,
#     933         options=options,
#     934         stream=stream,
#     935         stream_cls=stream_cls,
#     936         remaining_retries=remaining_retries,
#     937     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:1030, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1027         err.response.read()
#    1029     log.debug("Re-raising status error")
# -> 1030     raise self._make_status_error_from_response(err.response) from None
#    1032 return self._process_response(
#    1033     cast_to=cast_to,
#    1034     options=options,
#    (...)
#    1037     stream_cls=stream_cls,
#    1038 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your key*here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
events = eval(response_text)

# %%
first_event = events[0]
articles_text = "";

for link in first_event[1]:
    articles_text += scrape_article(link)

summary = prompt_openai(f"""Summarize the following text with three to five important bullet points: {articles_text}. Then, add the headline {first_event[0]}
at the top. Raw text, use line breaks to format. """)

summary

# %%
articles_text

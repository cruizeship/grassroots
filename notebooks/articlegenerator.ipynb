# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
import urllib.parse
from ast import *

# %%
location = "san francisco bay area"
topic = "economy"

# %%
def scrape_article(url):
    # Send a request to the URL
    response = requests.get(url)

    # Check if the request was successful
    # if response.status_code != 200:
      #  raise Exception(f"Failed to load page {url}, status code: {response.status_code}")

    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the relevant content
    # This part depends on the structure of the website. We'll use an example of a common structure.
    article_content = ''

    # Many news websites use <article> tag or specific class names for article content
    article = soup.find('article')
    if article:
        paragraphs = article.find_all('p')
    else:
        # Fallback to a generic method, searching for <p> tags within a div with a common class name
        paragraphs = soup.find_all('p')

    for p in paragraphs:
        article_content += p.get_text() + '\n'

    return article_content.strip()

# %%
def get_news_search_results(query, num_results):
    # Google news search URL with query
    search_url = f"https://www.google.com/search?q={query}&tbm=nws&num={num_results}"

    # Send a request to Google Search
    response = requests.get(search_url, headers={"User-Agent": "Mozilla/5.0"})
    response.raise_for_status()  # Check if the request was successful

    # Parse the response content with BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract the news headlines
    #soup.find_all('div', class_= 'BNeawe vvjwJb AP7Wnd'):
    
    divs = soup.find_all('div', class_='BNeawe vvjwJb AP7Wnd')
    articles = []
    
    if not divs:
        print("No news results found.")
        return
    
    for div in divs:
        # Extract headline text
        headline = div.text
        # Find the parent 'a' tag which contains the link
        link_tag = div.find_parent('a')
        # Extract the link URL
        if link_tag:
            # Google search results URLs are often prefixed with '/url?q='
            # Extract and decode the actual URL using urllib.parse
            raw_url = link_tag.get('href')
            if raw_url.startswith('/url?q='):
                url = urllib.parse.unquote(raw_url.split('/url?q=')[1].split('&sa=')[0])
            else:
                url = 'No valid link found'
        else:
            url = 'No link found'
            
        articles.append((headline, url))
            
    return articles

# %%
# Define the query and the number of results
query = f"{location} local news in the past week about {topic}"
num_results = 25
articles = []

# Get the news search results
news_search_results = get_news_search_results(query, num_results)

# Print the results
for i, result in enumerate(news_search_results, 1):
    # print(f"{i}. {result}")
    articles.append(result)

# %%
articles
# Out:
# [('Downtown San Jose visit activity soars, Oakland jumps, San Francisco nosedives',
#   'https://www.mercurynews.com/2024/05/09/economy-san-jose-oakland-downtown-jobs-restaurant-store-tech-property/'),
#  ('25000 fans headed to San Francisco for sold out rave with Skrillex, Fred Again',
#   'https://abc7news.com/post/sold-rave-25000-fans-headed-san-francisco-skrillex/14888819/'),
#  ('The APEC summit is happening this week in San Francisco. What is APEC, anyway?',
#   'https://www.nbcbayarea.com/news/local/apec-summit-san-francisco-explained/3369623/'),
#  ('How the Tri-Valley drives the local economy, embraces innovation - San Francisco Business Times',
#   'https://www.bizjournals.com/sanfrancisco/news/2024/02/16/tri-valley-drives-economy-embraces-innovation.html'),
#  ('What Happened to San Francisco, Really?',
#   'https://www.newyorker.com/magazine/2023/10/23/what-happened-to-san-francisco-really'),
#  ("Protesters Shut Down I-880 Freeway in Oakland as Part of 'Economic Blockade' for Gaza",
#   'https://www.kqed.org/news/11982940/protesters-shut-down-880-freeway-in-oakland-as-part-of-economic-blockade-for-gaza'),
#  ('APEC in San Francisco: Biden, Harris attend fundraiser as protesters chant outside',
#   'https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-18481349.php'),
#  ('Bay Area and California add jobs in April — but the gains are puny',
#   'https://www.mercurynews.com/2024/05/17/bay-area-job-tech-economy-covid-layoff-hotel-restaurant-store-april/'),
#  ("Here's what San Francisco's streets look like 3 weeks after APEC",
#   'https://www.nbcbayarea.com/news/local/san-francisco/san-francisco-streets-after-apec/3395312/'),
#  ('From Street Closures to Security Checks, What to Know About SF APEC 2023',
#   'https://www.kqed.org/news/11965942/from-street-closures-to-security-checks-what-to-know-about-sf-apec-2023'),
#  ('As APEC events wrap up, many San Francisco Chinatown businesses wait for the economic boost',
#   'https://abc7news.com/sf-chinatown-apec-business-san-francisco/14073667/'),
#  ("Thousands march against APEC in S.F.'s first major protest of summit",
#   'https://www.sfchronicle.com/bayarea/article/apec-protest-san-francisco-18483819.php'),
#  ('APEC Summit 2023: Day-by-day schedule of Asia Pacific Economic Cooperation in San Francisco',
#   'https://abc7news.com/apec-summit-san-francisco-schedule-asia-pacific-economic-cooperation-2023/14028661/'),
#  ("Trickle-down economics: Oakland Coliseum workers pay the price for A's move",
#   'https://www.sfchronicle.com/eastbay/article/oakland-coliseum-worker-employee-19397706.php'),
#  ('2023 APEC summit: Everything to know about San Francisco road closures, public transportation, security, tourism and more',
#   'https://abc7news.com/apec-2023-san-francisco-road-closures-summit-security-sf-safety/14022548/'),
#  ("When will San Francisco's economy hit bottom? Here's what experts say",
#   'https://www.sfchronicle.com/sf/article/san-francisco-economy-18362987.php'),
#  ('APEC in SF: Clearing homeless hot spots a priority for city',
#   'https://www.sfchronicle.com/sf/article/sf-apec-homeless-encampments-clear-hotspots-18478050.php'),
#  ('2025 NBA All-Star Game weekend to bring big boost to San Francisco Bay Area economy',
#   'https://abc7news.com/2025-nba-all-star-game-san-francisco-chase-center-tourism/14019899/'),
#  ('How APEC summit will make your San Francisco commute harder for an entire week',
#   'https://abc7news.com/apec-summit-san-francisco-road-closures-traffic/14009814/'),
#  ('APEC in San Francisco: Storms slow traffic as Biden hosts leaders at Legion of Honor, Harris leaves for L.A.',
#   'https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-protests-18494935.php'),
#  ("Drug addicts, homeless plaguing San Francisco's downtown miraculously disappear ahead of Biden, Xi Jinping summit",
#   'https://nypost.com/2023/11/10/news/san-francisco-clears-drug-addicts-and-homeless-out-of-downtown-ahead-of-biden-and-xi-jinping-summit/'),
#  ('Guide to San Francisco Fleet Week 2023',
#   'https://www.cbsnews.com/sanfrancisco/news/guide-to-san-francisco-fleet-week-2023/'),
#  ('California struggles with skyrocketing gas prices as summer comes to a close',
#   'https://www.cbsnews.com/sanfrancisco/news/california-struggles-with-skyrocketing-gas-prices-as-summer-comes-to-a-close/'),
#  ('APEC San Francisco: See Security, Traffic, Transit Maps',
#   'https://sfstandard.com/2023/11/07/san-francisco-apec-security-maps-transit-traffic/'),
#  ('‘Mood is dark’: 80% of Bay Area voters see state of big three downtowns as serious problem, poll finds',
#   'https://www.mercurynews.com/2023/10/01/mood-is-dark-80-of-bay-area-voters-see-state-of-big-three-downtowns-as-serious-problem-poll-finds/')]

# %%
def prompt_openai(prompt):
    api_key = "sk-proj-DpFFaCf3nHFx384aZQrmT3BlbkFJRsuMTVNdDhK3GQn1j4Si"
    client = OpenAI(api_key=api_key)
    completion = client.chat.completions.create(
      model="gpt-4o",
      messages=[
        {"role": "user", "content": prompt}
      ]
    )
    return completion.choices[0].message.content

# %%
prompt = f"""For the following list, give me a list of five important distinct events that are referenced by several articles (i.e. a short blurb). 
{articles} If it's not related to {topic} and/or it's not in {location}, don't account for it. If it's an opinion article or a guide, don't account for it.
It should be formatted as a python array of tuples, with the first item being the event title and the second item the links that pertain to it. The third item should be the image address of an image pertaining to it from a google search of the first item.. 
The event should be something distinct and not a general topic — i.e. the Golden Gate Bridge has shut down."
Please don't do things like '''python or /n, i should be able to assign the output text to a variable
"""
response_text = prompt_openai(prompt)
print(response_text)
# Out:
# [
#     ("APEC Summit 2023 in San Francisco",
#      [
#          "https://www.nbcbayarea.com/news/local/apec-summit-san-francisco-explained/3369623/",
#          "https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-18481349.php",
#          "https://www.nbcbayarea.com/news/local/san-francisco/san-francisco-streets-after-apec/3395312/",
#          "https://www.kqed.org/news/11965942/from-street-closures-to-security-checks-what-to-know-about-sf-apec-2023",
#          "https://abc7news.com/sf-chinatown-apec-business-san-francisco/14073667/",
#          "https://www.sfchronicle.com/bayarea/article/apec-protest-san-francisco-18483819.php",
#          "https://abc7news.com/apec-summit-san-francisco-schedule-asia-pacific-economic-cooperation-2023/14028661/",
#          "https://abc7news.com/apec-2023-san-francisco-road-closures-summit-security-sf-safety/14022548/",
#          "https://www.sfchronicle.com/sf/article/sf-apec-homeless-encampments-clear-hotspots-18478050.php",
#          "https://abc7news.com/apec-summit-san-francisco-road-closures-traffic/14009814/",
#          "https://www.sfchronicle.com/sf/article/apec-san-francisco-closures-traffic-protests-18494935.php",
#          "https://nypost.com/2023/11/10/news/san-francisco-clears-drug-addicts-and-homeless-out-of-downtown-ahead-of-biden-and-xi-jinping-summit/",
#          "https://sfstandard.com/2023/11/07/san-francisco-apec-security-maps-transit-traffic/"
#      ],
#      "https://example.com/image1.jpg"
#     ),
#     ("Downtown Economic Activity in the Bay Area",
#      [
#          "https://www.mercurynews.com/2024/05/09/economy-san-jose-oakland-downtown-jobs-restaurant-store-tech-property/",
#          "https://www.mercurynews.com/2024/05/17/bay-area-job-tech-economy-covid-layoff-hotel-restaurant-store-april/",
#          "https://www.newyorker.com/magazine/2023/10/23/what-happened-to-san-francisco-really",
#          "https://www.sfchronicle.com/sf/article/san-francisco-economy-18362987.php",
#          "https://www.mercurynews.com/2023/10/01/mood-is-dark-80-of-bay-area-voters-see-state-of-big-three-downtowns-as-serious-problem-poll-finds/"
#      ],
#      "https://example.com/image2.jpg"
#     ),
#     ("Protests in Oakland for Gaza",
#      [
#          "https://www.kqed.org/news/11982940/protesters-shut-down-880-freeway-in-oakland-as-part-of-economic-blockade-for-gaza"
#      ],
#      "https://example.com/image3.jpg"
#     ),
#     ("2025 NBA All-Star Game Economic Impact",
#      [
#          "https://abc7news.com/2025-nba-all-star-game-san-francisco-chase-center-tourism/14019899/"
#      ],
#      "https://example.com/image4.jpg"
#     ),
#     ("Oakland Coliseum Workers and the A's Move",
#      [
#          "https://www.sfchronicle.com/eastbay/article/oakland-coliseum-worker-employee-19397706.php"
#      ],
#      "https://example.com/image5.jpg"
#     )
# ]

# %%
events = eval(response_text)

# %%
# first_event = events[0]
# articles_text = "";

# index = 0
# for link in first_event[1]:
#     articles_text += scrape_article(link)
#     index += 1
#     if index == 5:
#         break
    
# summary = prompt_openai(f"""Summarize the following text with three to five important bullet points: {articles_text}. Then, add the headline {first_event[0]}
# at the top.""")

# summary

summaries = []

for event in events:
    summary_text = "";
    index = 0
    for link in event[1]:
        summary_text += scrape_article(link)
        index += 1
        if index == 5:
            break
    summary = prompt_openai(f"""Summarize the following text with three to five important bullet points: {summary_text}. Then, add the headline {event[0]}
    at the top.""")
    summary = summary.replace("\n", "")
    summaries.append((event[0], summary))

summaries
# Out:
# [('2023 APEC Summit in San Francisco',
#   "### 2023 APEC Summit in San Francisco- **APEC Summit Details:**  - The United States hosts the annual APEC summit for the first time since 2011.  - Leaders from the 21-member Asia-Pacific Economic Cooperation group discuss trade and economic growth.  - The key event is the meeting between President Joe Biden and Chinese President Xi Jinping amidst strained U.S.-China relations.- **Backdrop and Key Issues:**  - The summit occurs amid tensions from global issues like the Israel-Hamas conflict and Russia's invasion of Ukraine.  - Focus areas include making APEC economies more resilient to climate change and post-pandemic recovery.- **APEC's Role and Recent Developments:**  - APEC promotes trade and economic cooperation without binding agreements.  - There have been heightened security measures and public transit impacts across San Francisco due to the summit.  - **Local Impact and Community Response:**  - Chinatown and other local businesses have faced reduced tourism and customer traffic due to tight security.  - Community leaders and businesses initiate activities to attract visitors and boost local engagement.- **Security and Logistics:**  - Significant security zones and road closures have disrupted daily life in San Francisco, including impacts on public transit and local services."),
#  ('Downtown San Francisco Economic Decline',
#   "### Downtown San Francisco Economic Decline- **Economic and Social Challenges**: San Francisco faces a surge in vacant offices (nearly a quarter) and retail spaces, high drug-overdose deaths, a significant increase in property crimes, and a marked decline in public safety and cleanliness, leading to a negative national perception.  - **Business and Retail Exodus**: Major retailers like Nordstrom, Old Navy, and Williams-Sonoma have exited downtown, highlighting a broader economic decline, further compounded by the two-hundred-per-cent increase in car break-ins in 2021 and ongoing issues related to crime and homelessness.- **Historical Context and Urban Renewal**: Formerly seen as a model for urban renewal with lush parks, museums, and innovation-driven success, San Francisco's current economic woes contrast sharply with its past image. The city's struggle has invoked debates about the impact of tech industry reliance and rapid urban change.- **Policy and Leadership Responses**: Efforts to revive the downtown via new leadership, economic incentives, and proposed residential conversions face challenges. Controversial policies on public safety and law enforcement reflect ongoing debates about the best approaches to city management and crime reduction.- **Public Sentiment and Future Prospects**: Public opinion is deeply pessimistic, with a majority perceiving San Francisco as declining and expressing concerns over safety and cleanliness. Efforts by city officials, residents, and businesses to introduce innovative solutions and community engagement offer some hope for recovery, though challenges remain significant."),
#  ('Economic Impact of Job Growth and Loss in the Bay Area',
#   '### Economic Impact of Job Growth and Loss in the Bay Area- **April Job Market Trends:**  - The nine-county Bay Area added only 300 jobs, with California adding about 5,200 jobs statewide.  - Job growth was primarily powered by the East Bay, which gained 2,600 jobs; the South Bay remained flat, and the San Francisco-San Mateo area lost 1,700 jobs.- **Sector Performance:**  - The tech sector faced significant job cuts, with the region losing a total of 2,300 tech jobs. Companies like Tesla announced major layoffs involving thousands of positions.  - Health care showed resilience, adding 3,400 jobs, with significant contributions from the East Bay, San Francisco-San Mateo region, and South Bay.- **Economic Challenges:**  - High interest rates have adversely impacted interest-rate-sensitive sectors such as construction, manufacturing, and financial services, limiting hiring.  - Spending reductions in state and local budgets are contributing to employment challenges in the region.- **Long-term Outlook:**  - Experts suggest that despite current job market weaknesses, especially in the tech sector, the Bay Area has potential for long-term growth driven by emerging fields like artificial intelligence.  - **Population and Growth Dynamics:**  - Slow population growth is making hiring for local-serving sectors harder, adding another layer of complexity to the employment landscape.'),
#  ('Protests and Social Activism Impacting the Bay Area Economy',
#   "### Protests and Social Activism Impacting the Bay Area Economy- **Traffic Blockades and Law Enforcement Challenges**: Protesters blocked I-880 in Oakland and the Golden Gate Bridge, using methods such as chaining themselves to cement-filled drums and stationary vehicles, necessitating complex operations for law enforcement and leading to multiple arrests.- **Coordinated Economic Protests (A15)**: The protests were part of a multi-city effort to disrupt local and global economies, aiming to pressure divestment from Israel and its military suppliers. This included significant blockades in the Bay Area and other major cities around the world.- **Protesters' Demands and Statements**: Activists, including healthcare workers and community leaders, demanded a ceasefire and aid for Gaza, criticizing the violence and humanitarian impact of Israeli military actions in Palestine, emphasizing their actions were driven by frustration with symbolic gestures and a desire for tangible economic impact.- **Immediate Traffic Impacts**: Gradual reopening of the affected lanes on I-880 and the Golden Gate Bridge, after hours of blockage, underscored the immediate disruption caused by the protests, with ongoing law enforcement activity to disperse demonstrators and manage traffic flow.- **Historical Context and Continued Activism**: The current protests followed a series of pro-Palestinian actions in the Bay Area, part of an ongoing response to prolonged conflicts and humanitarian crises in Gaza, reflecting a growing trend of social activism targeting economic and infrastructural nodes to amplify their political messages."),
#  ('The 2025 NBA All-Star Game in San Francisco',
#   "### The 2025 NBA All-Star Game in San Francisco- The NBA All-Star weekend in February 2025 will feature numerous events across San Francisco and the Bay Area, including the dunk contest, three-point contest, and the All-Star game itself.- Local leaders anticipate the event will contribute approximately $350 million to the economy through hotel stays, restaurants, and transportation services.- Rodney Fong, President and CEO of the San Francisco Chamber of Commerce, highlighted that the NBA’s choice showcases the region's capacity to host major events, with the FIFA World Cup and Super Bowl also scheduled for 2026.- The selection of San Francisco for the event is seen as a positive indicator of the city's recovery post-pandemic and part of its broader comeback strategy.- Fans and officials alike are enthusiastic, viewing the event as confirmation of San Francisco's enduring appeal and capacity to host large-scale attractions.")]
